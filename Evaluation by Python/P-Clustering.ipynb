# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Loss Function Evaluation/Data/Clustering
# !ls

# %%
# !pip install clusteval
# !pip install pyclustering

# %%
import numpy as np
import pandas as pd
import scipy.stats
import statsmodels.api as sm
import matplotlib as plt
from sklearn.metrics import mutual_info_score
from sklearn.preprocessing import LabelEncoder
from scipy.spatial.distance import pdist, squareform
from clusteval import clusteval
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import fowlkes_mallows_score
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import fowlkes_mallows_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import normalized_mutual_info_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import adjusted_rand_score
from scipy.spatial.distance import cdist
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.datasets import make_regression
from sklearn.feature_selection import mutual_info_regression

# %% [markdown]
# **Data 1: Random**

# %%
X_random, y = make_blobs(random_state=42)
kmeans = KMeans(n_clusters=2, random_state=42)
clusters_random = kmeans.fit_predict(X_random)
centers_random = np.array([X_random[clusters_random == i].mean(axis=0) for i in range(kmeans.n_clusters)])

# %% [markdown]
# **Data 2: HC_DF_SPT_Head and Neck:**

# %%
data = pd.read_excel('HC_DF_SPT_Head and Neck.xlsx', header=None)

data.columns = data.columns.astype(str)
data = data.iloc[:, 1:]

num_features = data.shape[1]
column_names = [f'Feature{i+1}' for i in range(num_features)]
data.columns = column_names

scaler = StandardScaler()
scaled_features = scaler.fit_transform(data)

kmeans = KMeans(n_clusters=3, random_state=42)
y_pred = kmeans.fit_predict(scaled_features)
data['clusters'] = y_pred

data.to_excel('Processed_HC_DF_SPT_Head_and_Neck.xlsx', index=False)

# %%
processed_data = pd.read_excel('Processed_HC_DF_SPT_Head_and_Neck.xlsx')

n = processed_data.shape[1]-1
X_spt = processed_data.iloc[:, :n]

clusters_spt = processed_data['clusters']

n_spt = processed_data['clusters'].nunique()

centers_spt = np.array([X_spt[clusters_spt == i].mean(axis=0) for i in range(n_spt)])

# %% [markdown]
# **Data 3: HC_RF_PT_Head and Neck:**

# %%
data = pd.read_excel('HC_RF_PT_Head and Neck.xlsx', header=None)

data.columns = data.columns.astype(str)
data = data.iloc[:, 1:]

num_features = data.shape[1]
column_names = [f'Feature{i+1}' for i in range(num_features)]
data.columns = column_names

scaler = StandardScaler()
scaled_features = scaler.fit_transform(data)

kmeans = KMeans(n_clusters=3, random_state=42)
y_pred_pt = kmeans.fit_predict(scaled_features)

data['clusters'] = y_pred_pt

data.to_excel('Processed_HC_DF_PT_Head_and_Neck.xlsx', index=False)

# %%
data = pd.read_excel('HC_RF_PT_Head and Neck.xlsx', header=None)

data.columns = data.columns.astype(str)
data = data.iloc[:, 1:]

num_features = data.shape[1]
column_names = [f'Feature{i+1}' for i in range(num_features)]
data.columns = column_names

scaler = StandardScaler()
scaled_features = scaler.fit_transform(data)

kmeans = KMeans(n_clusters=3, random_state=42)
y_pred_pt = kmeans.fit_predict(scaled_features)

data['clusters'] = y_pred_pt

data.to_excel('Processed_HC_DF_PT_Head_and_Neck.xlsx', index=False)

# %%
data = pd.read_excel('LC_RF_PT_Lung.xlsx', header=None)

data.columns = data.columns.astype(str)
data = data.iloc[:, 1:]

num_features = data.shape[1]
column_names = [f'Feature{i+1}' for i in range(num_features)]
data.columns = column_names

scaler = StandardScaler()
scaled_features = scaler.fit_transform(data)

kmeans = KMeans(n_clusters=3, random_state=42)
y_pred_pt = kmeans.fit_predict(scaled_features)

data['clusters'] = y_pred_pt

data.to_excel('Processed_LC_RF_PT_Lung.xlsx', index=False)

# %%
pt_data = pd.read_excel('Processed_HC_DF_PT_Head_and_Neck.xlsx')

n= pt_data.shape[1]-1
X_pt = pt_data.iloc[:, :n]

clusters_pt = pt_data['clusters']

n_pt = pt_data['clusters'].nunique()

centers_pt = np.array([X_pt[clusters_pt == i].mean(axis=0) for i in range(n_pt)])

# %% [markdown]
# **Data5: LC_DF_SCT_Lung**

# %%
data = pd.read_excel('LC_DF_SCT_Lung.xlsx', header=None)

data.columns = data.columns.astype(str)
num_features = data.shape[1]
column_names = [f'Feature{i}' for i in range(num_features)]
data.columns = column_names


scaler = StandardScaler()
scaled_features = scaler.fit_transform(data)

kmeans = KMeans(n_clusters=3, random_state=42)
y_pred = kmeans.fit_predict(scaled_features)
data['clusters'] = y_pred

data.to_excel('Processed_LC_DF_SCT_Lung.xlsx', index=False)

# %%
sct_data = pd.read_excel('Processed_LC_DF_SCT_Lung.xlsx')

n= sct_data.shape[1]-1
X_sct = sct_data.iloc[:, :n]

clusters_sct =sct_data['clusters']

n_sct = sct_data['clusters'].nunique()

centers_sct = np.array([X_sct[clusters_sct == i].mean(axis=0) for i in range(n_sct)])

# %% [markdown]
# **Data6 : LC_DF_SPT_Lung**

# %%
data = pd.read_excel('LC_DF_SPT_Lung.xlsx', header=None)

data.columns = data.columns.astype(str)
num_features = data.shape[1]
column_names = [f'Feature{i}' for i in range(num_features)]
data.columns = column_names


scaler = StandardScaler()
scaled_features = scaler.fit_transform(data)

kmeans = KMeans(n_clusters=3, random_state=42)
y_pred = kmeans.fit_predict(scaled_features)
data['clusters'] = y_pred

data.to_excel('Processed_LC_DF_SPT_Lung.xlsx', index=False)

# %%
lspt_data = pd.read_excel('Processed_LC_DF_SPT_Lung.xlsx')

n= lspt_data.shape[1]-1
X_lspt = lspt_data.iloc[:, :n]

clusters_lspt =lspt_data['clusters']

n_lspt = lspt_data['clusters'].nunique()

centers_lspt = np.array([X_lspt[clusters_lspt == i].mean(axis=0) for i in range(n_lspt)])

# %% [markdown]
# **Data 7: LC_DF_CT_Lung**

# %%
data = pd.read_excel('LC_RF_CT_Lung.xlsx', header=None)

data.columns = data.columns.astype(str)
num_features = data.shape[1]
column_names = [f'Feature{i}' for i in range(num_features)]
data.columns = column_names


scaler = StandardScaler()
scaled_features = scaler.fit_transform(data)

kmeans = KMeans(n_clusters=3, random_state=42)
y_pred = kmeans.fit_predict(scaled_features)
data['clusters'] = y_pred

data.to_excel('Processed_RF_CT_Lung.xlsx', index=False)

# %%
lct_data = pd.read_excel('Processed_RF_CT_Lung.xlsx')

n= lct_data.shape[1]-1
X_lct = lct_data.iloc[:, :n]

clusters_lct =lct_data['clusters']

n_lct = lct_data['clusters'].nunique()

centers_lct = np.array([X_lct[clusters_lct == i].mean(axis=0) for i in range(n_lct)])

# %%
lpt_data = pd.read_excel('Processed_LC_RF_PT_Lung.xlsx')

n= lpt_data.shape[1]-1
X_lpt = lpt_data.iloc[:, :n]

clusters_lpt =lpt_data['clusters']

n_lpt = lpt_data['clusters'].nunique()

centers_lpt = np.array([X_lpt[clusters_lpt == i].mean(axis=0) for i in range(n)])

# %%
X = X_random
clusters = clusters_random
centers = centers_random

# %%
X = X_spt
clusters = clusters_spt
centers = centers_spt

# %%
X = X_sct
clusters =clusters_sct
centers = centers_sct

# %%
X = X_lspt
clusters = clusters_lspt
centers = centers_lspt

# %%
X = X_lct
clusters = clusters_lct
centers = centers_lct

# %%
X = X_lpt
clusters = clusters_lpt
centers = centers_lpt

# %% [markdown]
# Scikit Learn Library:

# %%
def Scikit_Learn (X,  clusters):
  return {
      'Silhouette Score': silhouette_score(X, clusters),
      'Davies Boundin Index' :  davies_bouldin_score(X, clusters),
      'Calinski Harabasz Score' : calinski_harabasz_score(X, clusters),
      'WCSS': kmeans.inertia_,
  }

# %% [markdown]
# Scipy Library:

# %%
def silhouette_score_index(X, labels):
    n_clusters = len(np.unique(labels))
    distances = cdist(X, X, 'euclidean')
    silhouette_vals = np.zeros(X.shape[0])

    for i in range(X.shape[0]):
        same_cluster = labels == labels[i]
        a = np.mean(distances[i, same_cluster])
        b = np.min([np.mean(distances[i, labels == other_cluster])
                    for other_cluster in np.unique(labels) if other_cluster != labels[i]])
        silhouette_vals[i] = (b - a) / max(a, b)

    return np.mean(silhouette_vals)



def davies_bouldin_index(X, labels):
    n_clusters = len(np.unique(labels))
    cluster_centroids = np.array([X[labels == i].mean(axis=0) for i in range(n_clusters)])
    S = np.zeros(n_clusters)
    for i in range(n_clusters):
        cluster_points = X[labels == i]
        centroid = cluster_centroids[i]
        S[i] = np.mean(cdist(cluster_points, [centroid]))

    M = cdist(cluster_centroids, cluster_centroids)

    np.fill_diagonal(M, np.inf)

    DB = np.mean([np.max((S[i] + S) / M[i]) for i in range(n_clusters)])

    return DB

import numpy as np
from scipy.spatial.distance import cdist

def calinski_harabasz_index(data, clusters):
    clusters = np.array(clusters)
    n_clusters = len(np.unique(clusters))
    n_samples = len(data)

    if n_clusters == 1 or n_clusters == n_samples:
        return np.nan

    overall_centroid = np.mean(data, axis=0)
    b_dispersion = 0.0
    w_dispersion = 0.0

    for i in np.unique(clusters):

        cluster_data = data[clusters == i]

        cluster_centroid = np.mean(cluster_data, axis=0)

        b_dispersion += len(cluster_data) * np.sum((cluster_centroid - overall_centroid) ** 2)

        w_dispersion += np.sum((cluster_data - cluster_centroid) ** 2)

    ch_index = (b_dispersion / (n_clusters - 1)) / (w_dispersion / (n_samples - n_clusters))

    return ch_index




def Scipy (X, clusters, centers):
  return {
      'Silhouette Score': silhouette_score_index(X, clusters),
      'Davies Boundin Index' :  davies_bouldin_index(X, clusters),
      'Calinski Harabasz Score' : calinski_harabasz_index(X.values, clusters.values),
  }

# %%
results = {
    'Scikit Learn': Scikit_Learn(X, clusters),
    'Scipy' : Scipy(X, clusters, centers),

}

# %%
results_df = pd.DataFrame(results).T
results_df.reset_index(inplace = True)
results_df = results_df.rename_axis(None, axis = 1)
pd.set_option('display.float_format', '{:.20f}'.format)

print(results_df)
