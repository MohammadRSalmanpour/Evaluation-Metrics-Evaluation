# %% [markdown]
# # MAE

# %%
options(digits = 17)

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
library(readxl)

data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
mae_base <- mean(abs(y_true - y_pred))

#  Metrics
mae_metrics <- Metrics::mae(y_true, y_pred)

#  yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
mae_yardstick <- mae_vec(data$truth, data$prediction)  
#  MLmetrics
mae_mlmetrics <- MAE(y_true, y_pred)

#  ModelMetrics
mae_modelmetrics <- ModelMetrics::mae(y_true, y_pred)

#  caret
mae_caret <- caret::MAE(y_pred, y_true)

#  forecast
mae_forecast <- accuracy(y_pred, y_true)[, "MAE"]

# e1071
mae_e1071 <- NA

#  hydroGOF
mae_hydroGOF <- hydroGOF::mae(y_true, y_pred)

#  simstudy
mae_simstudy <- NA

#  tdr
mae_tdr <- tdStats(m = y_pred,o = y_true,"mae")

#  rminer
mae_rminer <- mmetric(y_true, y_pred, metric = "MAE")

#  FNN
mae_fnn <- NA

#  simEd
mae_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  MAE = c(mae_base, mae_metrics, mae_yardstick, mae_mlmetrics, 
          mae_modelmetrics, mae_caret, mae_forecast, mae_e1071, mae_hydroGOF, 
          mae_simstudy, mae_tdr, mae_rminer, mae_fnn, mae_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
#          Method                MAE
# 1        Base-R 657.87516853932584
# 2       Metrics 657.87516853932584
# 3     yardstick 657.87516853932584
# 4     MLmetrics 657.87516853932584
# 5  ModelMetrics 657.87516853932584
# 6         caret 657.87516853932584
# 7      forecast 657.87516853932584
# 8         e1071                 NA
# 9      hydroGOF 657.87516853932584
# 10     simstudy                 NA
# 11          tdr 657.87516853932584
# 12       rminer 657.87516853932584
# 13          FNN                 NA
# 14        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
library(readxl)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
mae_base <- mean(abs(y_true - y_pred))

#  Metrics
mae_metrics <- Metrics::mae(y_true, y_pred)

#  yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
mae_yardstick <- mae_vec(data$truth, data$prediction) 
#  MLmetrics
mae_mlmetrics <- MAE(y_true, y_pred)

#  ModelMetrics
mae_modelmetrics <- ModelMetrics::mae(y_true, y_pred)

#  caret
mae_caret <- caret::MAE(y_pred, y_true)

#  forecast
mae_forecast <- accuracy(y_pred, y_true)[, "MAE"]

# e1071
mae_e1071 <- NA

#  hydroGOF
mae_hydroGOF <- hydroGOF::mae(y_true, y_pred)

#  simstudy
mae_simstudy <- NA

#  tdr
mae_tdr <- tdStats(m = y_pred,o = y_true,"mae")

#  rminer
mae_rminer <- mmetric(y_true, y_pred, metric = "MAE")

#  FNN
mae_fnn <- NA

#  simEd
mae_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  MAE = c(mae_base, mae_metrics, mae_yardstick, mae_mlmetrics, 
          mae_modelmetrics, mae_caret, mae_forecast, mae_e1071, mae_hydroGOF, 
          mae_simstudy, mae_tdr, mae_rminer, mae_fnn, mae_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   2176.4299999999998
# 2 1521   1543.0300000000000
# 3 2799   1988.4900000000000
# 4 1452   1713.4500000000000
# 5 1269   1582.0300000000000
# 6 2413   1798.1500000000001
#          Method                MAE
# 1        Base-R 700.08039325842697
# 2       Metrics 700.08039325842697
# 3     yardstick 700.08039325842697
# 4     MLmetrics 700.08039325842697
# 5  ModelMetrics 700.08039325842697
# 6         caret 700.08039325842697
# 7      forecast 700.08039325842697
# 8         e1071                 NA
# 9      hydroGOF 700.08039325842697
# 10     simstudy                 NA
# 11          tdr 700.08039325842697
# 12       rminer 700.08039325842697
# 13          FNN                 NA
# 14        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
library(readxl)

data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
mae_base <- mean(abs(y_true - y_pred))

#  Metrics
mae_metrics <- Metrics::mae(y_true, y_pred)

#  yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
mae_yardstick <- mae_vec(data$truth, data$prediction)  
#  MLmetrics
mae_mlmetrics <- MAE(y_true, y_pred)

#  ModelMetrics
mae_modelmetrics <- ModelMetrics::mae(y_true, y_pred)

#  caret
mae_caret <- caret::MAE(y_pred, y_true)

#  forecast
mae_forecast <- accuracy(y_pred, y_true)[, "MAE"]

# e1071
mae_e1071 <- NA

#  hydroGOF
mae_hydroGOF <- hydroGOF::mae(y_true, y_pred)

#  simstudy
mae_simstudy <- NA

#  tdr
mae_tdr <- tdStats(m = y_pred,o = y_true,"mae")

#  rminer
mae_rminer <- mmetric(y_true, y_pred, metric = "MAE")

#  FNN
mae_fnn <- NA

#  simEd
mae_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  MAE = c(mae_base, mae_metrics, mae_yardstick, mae_mlmetrics, 
          mae_modelmetrics, mae_caret, mae_forecast, mae_e1071, mae_hydroGOF, 
          mae_simstudy, mae_tdr, mae_rminer, mae_fnn, mae_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
#          Method                MAE
# 1        Base-R 699.29056179775284
# 2       Metrics 699.29056179775284
# 3     yardstick 699.29056179775284
# 4     MLmetrics 699.29056179775284
# 5  ModelMetrics 699.29056179775284
# 6         caret 699.29056179775284
# 7      forecast 699.29056179775284
# 8         e1071                 NA
# 9      hydroGOF 699.29056179775284
# 10     simstudy                 NA
# 11          tdr 699.29056179775284
# 12       rminer 699.29056179775284
# 13          FNN                 NA
# 14        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
library(readxl)

y_true <- c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred <- c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)

#  Base-R
mae_base <- mean(abs(y_true - y_pred))

#  Metrics
mae_metrics <- Metrics::mae(y_true, y_pred)

#  yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
mae_yardstick <- mae_vec(data$truth, data$prediction) 
#  MLmetrics
mae_mlmetrics <- MAE(y_true, y_pred)

#  ModelMetrics
mae_modelmetrics <- ModelMetrics::mae(y_true, y_pred)

#  caret
mae_caret <- caret::MAE(y_pred, y_true)

#  forecast
mae_forecast <- accuracy(y_pred, y_true)[, "MAE"]

# e1071
mae_e1071 <- NA

#  hydroGOF
mae_hydroGOF <- hydroGOF::mae(y_true, y_pred)

#  simstudy
mae_simstudy <- NA

#  tdr
mae_tdr <- tdStats(m = y_pred,o = y_true,"mae")

#  rminer
mae_rminer <- mmetric(y_true, y_pred, metric = "MAE")

#  FNN
mae_fnn <- NA

#  simEd
mae_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  MAE = c(mae_base, mae_metrics, mae_yardstick, mae_mlmetrics, 
          mae_modelmetrics, mae_caret, mae_forecast, mae_e1071, mae_hydroGOF, 
          mae_simstudy, mae_tdr, mae_rminer, mae_fnn, mae_simEd)
)

print(results)
# Out:
#          Method                 MAE
# 1        Base-R 0.57142857142857151
# 2       Metrics 0.57142857142857151
# 3     yardstick 0.57142857142857151
# 4     MLmetrics 0.57142857142857151
# 5  ModelMetrics 0.57142857142857151
# 6         caret 0.57142857142857151
# 7      forecast 0.57142857142857151
# 8         e1071                  NA
# 9      hydroGOF 0.57142857142857151
# 10     simstudy                  NA
# 11          tdr 0.57142857142857151
# 12       rminer 0.57142857142857151
# 13          FNN                  NA
# 14        simEd                  NA

# %% [markdown]
# # MSE

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
mse_base <- mean((y_true - y_pred)^2)

#  Metrics
mse_metrics <- Metrics::mse(y_true, y_pred)

# yardstick
mse_yardstick <- NA

# MLmetrics
mse_mlmetrics <-  MLmetrics::MSE(y_true, y_pred)

# ModelMetrics
mse_modelmetrics <- ModelMetrics::mse(y_true, y_pred)

# caret
mse_caret <- NA 

# forecast
rmse_forecast <- accuracy(y_pred, y_true)[, "RMSE"]
mse_forecast <- rmse_forecast^2

# e1071
mse_e1071 <- NA

# hydroGOF
mse_hydroGOF <- hydroGOF::mse(y_pred, y_true)

# simstudy
mse_simstudy <- NA

# tdr
mse_tdr <- tdStats(m = y_pred,o = y_true,"mse")

# rminer
mse_rminer <- mmetric(y_true, y_pred, metric = "MSE")

# FNN
mse_fnn <- NA

# simEd
mse_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  MSE = c(mse_base, mse_metrics, mse_yardstick, mse_mlmetrics, 
          mse_modelmetrics, mse_caret, mse_forecast, mse_e1071, mse_hydroGOF, 
          mse_simstudy, mse_tdr, mse_rminer, mse_fnn, mse_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
#          Method                MSE
# 1        Base-R 688970.14196516853
# 2       Metrics 688970.14196516853
# 3     yardstick                 NA
# 4     MLmetrics 688970.14196516853
# 5  ModelMetrics 688970.14196516853
# 6         caret                 NA
# 7      forecast 688970.14196516853
# 8         e1071                 NA
# 9      hydroGOF 688970.14196516853
# 10     simstudy                 NA
# 11          tdr 688970.14196516853
# 12       rminer 688970.14196516853
# 13          FNN                 NA
# 14        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
mse_base <- mean((y_true - y_pred)^2)

#  Metrics
mse_metrics <- Metrics::mse(y_true, y_pred)

# yardstick
mse_yardstick <- NA

# MLmetrics
mse_mlmetrics <-  MLmetrics::MSE(y_true, y_pred)

# ModelMetrics
mse_modelmetrics <- ModelMetrics::mse(y_true, y_pred)

# caret
mse_caret <- NA 

# forecast
rmse_forecast <- accuracy(y_pred, y_true)[, "RMSE"]
mse_forecast <- rmse_forecast^2

# e1071
mse_e1071 <- NA

# hydroGOF
mse_hydroGOF <- hydroGOF::mse(y_pred, y_true)

# simstudy
mse_simstudy <- NA

# tdr
mse_tdr <- tdStats(m = y_pred,o = y_true,"mse")

# rminer
mse_rminer <- mmetric(y_true, y_pred, metric = "MSE")

# FNN
mse_fnn <- NA

# simEd
mse_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  MSE = c(mse_base, mse_metrics, mse_yardstick, mse_mlmetrics, 
          mse_modelmetrics, mse_caret, mse_forecast, mse_e1071, mse_hydroGOF, 
          mse_simstudy, mse_tdr, mse_rminer, mse_fnn, mse_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   2176.4299999999998
# 2 1521   1543.0300000000000
# 3 2799   1988.4900000000000
# 4 1452   1713.4500000000000
# 5 1269   1582.0300000000000
# 6 2413   1798.1500000000001
#          Method               MSE
# 1        Base-R 724900.1027938202
# 2       Metrics 724900.1027938202
# 3     yardstick                NA
# 4     MLmetrics 724900.1027938202
# 5  ModelMetrics 724900.1027938202
# 6         caret                NA
# 7      forecast 724900.1027938202
# 8         e1071                NA
# 9      hydroGOF 724900.1027938202
# 10     simstudy                NA
# 11          tdr 724900.1027938202
# 12       rminer 724900.1027938202
# 13          FNN                NA
# 14        simEd                NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
mse_base <- mean((y_true - y_pred)^2)

#  Metrics
mse_metrics <- Metrics::mse(y_true, y_pred)

# yardstick
mse_yardstick <- NA

# MLmetrics
mse_mlmetrics <-  MLmetrics::MSE(y_true, y_pred)

# ModelMetrics
mse_modelmetrics <- ModelMetrics::mse(y_true, y_pred)

# caret
mse_caret <- NA 

# forecast
rmse_forecast <- accuracy(y_pred, y_true)[, "RMSE"]
mse_forecast <- rmse_forecast^2

# e1071
mse_e1071 <- NA

# hydroGOF
mse_hydroGOF <- hydroGOF::mse(y_pred, y_true)

# simstudy
mse_simstudy <- NA

# tdr
mse_tdr <- tdStats(m = y_pred,o = y_true,"mse")

# rminer
mse_rminer <- mmetric(y_true, y_pred, metric = "MSE")

# FNN
mse_fnn <- NA

# simEd
mse_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  MSE = c(mse_base, mse_metrics, mse_yardstick, mse_mlmetrics, 
          mse_modelmetrics, mse_caret, mse_forecast, mse_e1071, mse_hydroGOF, 
          mse_simstudy, mse_tdr, mse_rminer, mse_fnn, mse_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
#          Method                MSE
# 1        Base-R 749309.72976966295
# 2       Metrics 749309.72976966295
# 3     yardstick                 NA
# 4     MLmetrics 749309.72976966295
# 5  ModelMetrics 749309.72976966295
# 6         caret                 NA
# 7      forecast 749309.72976966295
# 8         e1071                 NA
# 9      hydroGOF 749309.72976966295
# 10     simstudy                 NA
# 11          tdr 749309.72976966295
# 12       rminer 749309.72976966295
# 13          FNN                 NA
# 14        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
y_true <- c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred <- c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)

#  Base-R
mse_base <- mean((y_true - y_pred)^2)

#  Metrics
mse_metrics <- Metrics::mse(y_true, y_pred)

# yardstick
mse_yardstick <- NA

# MLmetrics
mse_mlmetrics <-  MLmetrics::MSE(y_true, y_pred)

# ModelMetrics
mse_modelmetrics <- ModelMetrics::mse(y_true, y_pred)

# caret
mse_caret <- NA 

# forecast
rmse_forecast <- accuracy(y_pred, y_true)[, "RMSE"]
mse_forecast <- rmse_forecast^2

# e1071
mse_e1071 <- NA

# hydroGOF
mse_hydroGOF <- hydroGOF::mse(y_pred, y_true)

# simstudy
mse_simstudy <- NA

# tdr
mse_tdr <- tdStats(m = y_pred,o = y_true,"mse")

# rminer
mse_rminer <- mmetric(y_true, y_pred, metric = "MSE")

# FNN
mse_fnn <- NA

# simEd
mse_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  MSE = c(mse_base, mse_metrics, mse_yardstick, mse_mlmetrics, 
          mse_modelmetrics, mse_caret, mse_forecast, mse_e1071, mse_hydroGOF, 
          mse_simstudy, mse_tdr, mse_rminer, mse_fnn, mse_simEd)
)

print(results)
# Out:
#          Method                 MSE
# 1        Base-R 0.63428571428571434
# 2       Metrics 0.63428571428571434
# 3     yardstick                  NA
# 4     MLmetrics 0.63428571428571434
# 5  ModelMetrics 0.63428571428571434
# 6         caret                  NA
# 7      forecast 0.63428571428571423
# 8         e1071                  NA
# 9      hydroGOF 0.63428571428571434
# 10     simstudy                  NA
# 11          tdr 0.63428571428571434
# 12       rminer 0.63428571428571434
# 13          FNN                  NA
# 14        simEd                  NA

# %% [markdown]
# # RMSE

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
#  Base-R
rmse_base <- sqrt(mean((y_true - y_pred)^2))

# Metrics
rmse_metrics <- Metrics::rmse(y_true, y_pred)

# yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
rmse_yardstick <- yardstick::rmse(data, truth = truth, estimate = prediction) %>%
  dplyr::pull(.estimate)

# MLmetrics
rmse_mlmetrics <-  MLmetrics::RMSE(y_pred, y_true)

# ModelMetrics
rmse_modelmetrics <- ModelMetrics::rmse(y_true, y_pred)

# caret
rmse_caret <- caret::RMSE(y_pred, y_true)

# forecast
rmse_forecast <- forecast::accuracy(y_pred, y_true)[, "RMSE"]

# e1071
rmse_e1071 <- NA

# hydroGOF
rmse_hydroGOF <-  hydroGOF::rmse(y_true, y_pred)

# simstudy
rmse_simstudy <- NA

# tdr
rmse_tdr <- tdStats(m = y_pred,o = y_true,"rmse")

# rminer
rmse_rminer <- rminer::mmetric(y_true, y_pred, metric = "RMSE")

# FNN
rmse_fnn <- NA

# simEd
rmse_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  RMSE = c(rmse_base, rmse_metrics, rmse_yardstick, rmse_mlmetrics, 
           rmse_modelmetrics, rmse_caret, rmse_forecast, rmse_e1071, 
           rmse_hydroGOF, rmse_simstudy, rmse_tdr, rmse_rminer, 
           rmse_fnn, rmse_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
#          Method               RMSE
# 1        Base-R 830.04225312038693
# 2       Metrics 830.04225312038693
# 3     yardstick 830.04225312038693
# 4     MLmetrics 830.04225312038693
# 5  ModelMetrics 830.04225312038693
# 6         caret 830.04225312038693
# 7      forecast 830.04225312038693
# 8         e1071                 NA
# 9      hydroGOF 830.04225312038693
# 10     simstudy                 NA
# 11          tdr 830.04225312038693
# 12       rminer 830.04225312038693
# 13          FNN                 NA
# 14        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)

data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
rmse_base <- sqrt(mean((y_true - y_pred)^2))

# Metrics
rmse_metrics <- Metrics::rmse(y_true, y_pred)

# yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
rmse_yardstick <- yardstick::rmse(data, truth = truth, estimate = prediction) %>%
  dplyr::pull(.estimate)

# MLmetrics
rmse_mlmetrics <-  MLmetrics::RMSE(y_pred, y_true)

# ModelMetrics
rmse_modelmetrics <- ModelMetrics::rmse(y_true, y_pred)

# caret
rmse_caret <- caret::RMSE(y_pred, y_true)

# forecast
rmse_forecast <- forecast::accuracy(y_pred, y_true)[, "RMSE"]

# e1071
rmse_e1071 <- NA

# hydroGOF
rmse_hydroGOF <-  hydroGOF::rmse(y_true, y_pred)

# simstudy
rmse_simstudy <- NA

# tdr
rmse_tdr <- tdStats(m = y_pred,o = y_true,"rmse")

# rminer
rmse_rminer <- rminer::mmetric(y_true, y_pred, metric = "RMSE")

# FNN
rmse_fnn <- NA

# simEd
rmse_simEd <- NA

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  RMSE = c(rmse_base, rmse_metrics, rmse_yardstick, rmse_mlmetrics, 
           rmse_modelmetrics, rmse_caret, rmse_forecast, rmse_e1071, 
           rmse_hydroGOF, rmse_simstudy, rmse_tdr, rmse_rminer, 
           rmse_fnn, rmse_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   2176.4299999999998
# 2 1521   1543.0300000000000
# 3 2799   1988.4900000000000
# 4 1452   1713.4500000000000
# 5 1269   1582.0300000000000
# 6 2413   1798.1500000000001
#          Method               RMSE
# 1        Base-R 851.41065461610253
# 2       Metrics 851.41065461610253
# 3     yardstick 851.41065461610253
# 4     MLmetrics 851.41065461610253
# 5  ModelMetrics 851.41065461610253
# 6         caret 851.41065461610253
# 7      forecast 851.41065461610253
# 8         e1071                 NA
# 9      hydroGOF 851.41065461610253
# 10     simstudy                 NA
# 11          tdr 851.41065461610253
# 12       rminer 851.41065461610253
# 13          FNN                 NA
# 14        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
rmse_base <- sqrt(mean((y_true - y_pred)^2))

# Metrics
rmse_metrics <- Metrics::rmse(y_true, y_pred)

# yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
rmse_yardstick <- yardstick::rmse(data, truth = truth, estimate = prediction) %>%
  dplyr::pull(.estimate)

# MLmetrics
rmse_mlmetrics <-  MLmetrics::RMSE(y_pred, y_true)

# ModelMetrics
rmse_modelmetrics <- ModelMetrics::rmse(y_true, y_pred)

# caret
rmse_caret <- caret::RMSE(y_pred, y_true)

# forecast
rmse_forecast <- forecast::accuracy(y_pred, y_true)[, "RMSE"]

# e1071
rmse_e1071 <- NA

# hydroGOF
rmse_hydroGOF <-  hydroGOF::rmse(y_true, y_pred)

# simstudy
rmse_simstudy <- NA

# tdr
rmse_tdr <- tdStats(m = y_pred,o = y_true,"rmse")

# rminer
rmse_rminer <- rminer::mmetric(y_true, y_pred, metric = "RMSE")

# FNN
rmse_fnn <- NA

# simEd
rmse_simEd <- NA

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  RMSE = c(rmse_base, rmse_metrics, rmse_yardstick, rmse_mlmetrics, 
           rmse_modelmetrics, rmse_caret, rmse_forecast, rmse_e1071, 
           rmse_hydroGOF, rmse_simstudy, rmse_tdr, rmse_rminer, 
           rmse_fnn, rmse_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
#          Method               RMSE
# 1        Base-R 865.62678434164854
# 2       Metrics 865.62678434164854
# 3     yardstick 865.62678434164854
# 4     MLmetrics 865.62678434164854
# 5  ModelMetrics 865.62678434164854
# 6         caret 865.62678434164854
# 7      forecast 865.62678434164854
# 8         e1071                 NA
# 9      hydroGOF 865.62678434164854
# 10     simstudy                 NA
# 11          tdr 865.62678434164854
# 12       rminer 865.62678434164854
# 13          FNN                 NA
# 14        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(tdr)
library(rminer)
library(FNN)
library(simEd)
y_true = c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred = c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)
#  Base-R
rmse_base <- sqrt(mean((y_true - y_pred)^2))

# Metrics
rmse_metrics <- Metrics::rmse(y_true, y_pred)

# yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
rmse_yardstick <- yardstick::rmse(data, truth = truth, estimate = prediction) %>%
  dplyr::pull(.estimate)

# MLmetrics
rmse_mlmetrics <-  MLmetrics::RMSE(y_pred, y_true)

# ModelMetrics
rmse_modelmetrics <- ModelMetrics::rmse(y_true, y_pred)

# caret
rmse_caret <- caret::RMSE(y_pred, y_true)

# forecast
rmse_forecast <- forecast::accuracy(y_pred, y_true)[, "RMSE"]

# e1071
rmse_e1071 <- NA

# hydroGOF
rmse_hydroGOF <-  hydroGOF::rmse(y_true, y_pred)

# simstudy
rmse_simstudy <- NA

# tdr
rmse_tdr <- tdStats(m = y_pred,o = y_true,"rmse")

# rminer
rmse_rminer <- rminer::mmetric(y_true, y_pred, metric = "RMSE")

# FNN
rmse_fnn <- NA

# simEd
rmse_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "tdr", "rminer", "FNN", "simEd"),
  RMSE = c(rmse_base, rmse_metrics, rmse_yardstick, rmse_mlmetrics, 
           rmse_modelmetrics, rmse_caret, rmse_forecast, rmse_e1071, 
           rmse_hydroGOF, rmse_simstudy, rmse_tdr, rmse_rminer, 
           rmse_fnn, rmse_simEd)
)

print(results)
# Out:
#          Method               RMSE
# 1        Base-R 0.7964205637009345
# 2       Metrics 0.7964205637009345
# 3     yardstick 0.7964205637009345
# 4     MLmetrics 0.7964205637009345
# 5  ModelMetrics 0.7964205637009345
# 6         caret 0.7964205637009345
# 7      forecast 0.7964205637009345
# 8         e1071                 NA
# 9      hydroGOF 0.7964205637009345
# 10     simstudy                 NA
# 11          tdr 0.7964205637009345
# 12       rminer 0.7964205637009345
# 13          FNN                 NA
# 14        simEd                 NA

# %% [markdown]
# # R-squared

# %%
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
ss_total <- sum((y_true - mean(y_true))^2)
ss_residual <- sum((y_true - y_pred)^2)
r_squared_base <- 1 - (ss_residual / ss_total)

#  Metrics
r_squared_metrics <- NA

# yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
r_squared_yardstick <- yardstick::rsq(data, truth = truth, estimate = prediction) %>%
  dplyr::pull(.estimate)

# MLmetrics
r_squared_mlmetrics <- MLmetrics::R2_Score(y_pred, y_true)

# ModelMetrics
r_squared_modelmetrics <- NA

# caret
r_squared_caret <- caret::R2(y_pred, y_true)

# forecast
r_squared_forecast <- NA

# e1071
r_squared_e1071 <- NA

# hydroGOF
r_squared_hydroGOF <- NA

# simstudy
r_squared_simstudy <- NA

# rminer
r_squared_rminer <- rminer::mmetric(y_true, y_pred, metric = "R2")

# FNN
r_squared_fnn <- NA

# simEd
r_squared_simEd <- NA

# tdr
tdr_r2 = tdStats(m = y_pred,o = y_true,"r2")
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd", "tdr"),
  R_squared = c(r_squared_base, r_squared_metrics, r_squared_yardstick, 
                r_squared_mlmetrics, r_squared_modelmetrics, 
                r_squared_caret, r_squared_forecast, r_squared_e1071, 
                r_squared_hydroGOF, r_squared_simstudy, r_squared_rminer, 
                r_squared_fnn, r_squared_simEd, tdr_r2)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
#          Method            R_squared
# 1        Base-R 0.050931537223652290
# 2       Metrics                   NA
# 3     yardstick 0.069342151932532875
# 4     MLmetrics 0.050931537223652290
# 5  ModelMetrics                   NA
# 6         caret 0.069342151932533042
# 7      forecast                   NA
# 8         e1071                   NA
# 9      hydroGOF                   NA
# 10     simstudy                   NA
# 11       rminer 0.069342151932533042
# 12          FNN                   NA
# 13        simEd                   NA
# 14          tdr 0.069342151932533042

# %%
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R
ss_total <- sum((y_true - mean(y_true))^2)
ss_residual <- sum((y_true - y_pred)^2)
r_squared_base <- 1 - (ss_residual / ss_total)

#  Metrics
r_squared_metrics <- NA

# yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
r_squared_yardstick <- yardstick::rsq(data, truth = truth, estimate = prediction) %>%
  dplyr::pull(.estimate)

# MLmetrics
r_squared_mlmetrics <- MLmetrics::R2_Score(y_pred, y_true)

# ModelMetrics
r_squared_modelmetrics <- NA

# caret
r_squared_caret <- caret::R2(y_pred, y_true)

# forecast
r_squared_forecast <- NA

# e1071
r_squared_e1071 <- NA

# hydroGOF
r_squared_hydroGOF <- NA

# simstudy
r_squared_simstudy <- NA

# rminer
r_squared_rminer <- rminer::mmetric(y_true, y_pred, metric = "R2")

# FNN
r_squared_fnn <- NA

# simEd
r_squared_simEd <- NA

# tdr
tdr_r2 = tdStats(m = y_pred,o = y_true,"r2")

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd", "tdr"),
  R_squared = c(r_squared_base, r_squared_metrics, r_squared_yardstick, 
                r_squared_mlmetrics, r_squared_modelmetrics, 
                r_squared_caret, r_squared_forecast, r_squared_e1071, 
                r_squared_hydroGOF, r_squared_simstudy, r_squared_rminer, 
                r_squared_fnn, r_squared_simEd, tdr_r2)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   2176.4299999999998
# 2 1521   1543.0300000000000
# 3 2799   1988.4900000000000
# 4 1452   1713.4500000000000
# 5 1269   1582.0300000000000
# 6 2413   1798.1500000000001
#          Method             R_squared
# 1        Base-R 0.0014373855699992832
# 2       Metrics                    NA
# 3     yardstick 0.0355587478374383356
# 4     MLmetrics 0.0014373855699992832
# 5  ModelMetrics                    NA
# 6         caret 0.0355587478374383356
# 7      forecast                    NA
# 8         e1071                    NA
# 9      hydroGOF                    NA
# 10     simstudy                    NA
# 11       rminer 0.0355587478374383356
# 12          FNN                    NA
# 13        simEd                    NA
# 14          tdr 0.0355587478374383356

# %%
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

#  Base-R

#  Metrics
r_squared_metrics <- NA

# yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
r_squared_yardstick <- yardstick::rsq(data, truth = truth, estimate = prediction) %>%
  dplyr::pull(.estimate)

# MLmetrics
r_squared_mlmetrics <- MLmetrics::R2_Score(y_pred, y_true)

# ModelMetrics
r_squared_modelmetrics <- NA

# caret
r_squared_caret <- caret::R2(y_pred, y_true)

# forecast
r_squared_forecast <- NA

# e1071
r_squared_e1071 <- NA

# hydroGOF
r_squared_hydroGOF <- NA

# simstudy
r_squared_simstudy <- NA

# rminer
r_squared_rminer <- rminer::mmetric(y_true, y_pred, metric = "R2")

# FNN
r_squared_fnn <- NA

# simEd
r_squared_simEd <- NA

# tdr
tdr_r2 = tdStats(m = y_pred,o = y_true,"r2")

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd", "tdr"),
  R_squared = c(r_squared_base, r_squared_metrics, r_squared_yardstick, 
                r_squared_mlmetrics, r_squared_modelmetrics, 
                r_squared_caret, r_squared_forecast, r_squared_e1071, 
                r_squared_hydroGOF, r_squared_simstudy, r_squared_rminer, 
                r_squared_fnn, r_squared_simEd, tdr_r2)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
#          Method             R_squared
# 1        Base-R -0.032187304006284778
# 2       Metrics                    NA
# 3     yardstick  0.022174830394867347
# 4     MLmetrics -0.032187304006284778
# 5  ModelMetrics                    NA
# 6         caret  0.022174830394867329
# 7      forecast                    NA
# 8         e1071                    NA
# 9      hydroGOF                    NA
# 10     simstudy                    NA
# 11       rminer  0.022174830394867329
# 12          FNN                    NA
# 13        simEd                    NA
# 14          tdr  0.022174830394867329

# %%
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
y_true = c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred = c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)
#  Base-R
ss_total <- sum((y_true - mean(y_true))^2)
ss_residual <- sum((y_true - y_pred)^2)
r_squared_base <- 1 - (ss_residual / ss_total)

#  Metrics
r_squared_metrics <- NA

# yardstick
library(tibble)
data <- tibble(truth = y_true, prediction = y_pred)
r_squared_yardstick <- yardstick::rsq(data, truth = truth, estimate = prediction) %>%
  dplyr::pull(.estimate)

# MLmetrics
r_squared_mlmetrics <- MLmetrics::R2_Score(y_pred, y_true)

# ModelMetrics
r_squared_modelmetrics <- NA

# caret
r_squared_caret <- caret::R2(y_pred, y_true)

# forecast
r_squared_forecast <- NA

# e1071
r_squared_e1071 <- NA

# hydroGOF
r_squared_hydroGOF <- NA

# simstudy
r_squared_simstudy <- NA

# rminer
r_squared_rminer <- rminer::mmetric(y_true, y_pred, metric = "R2")

# FNN
r_squared_fnn <- NA

# simEd
r_squared_simEd <- NA

# tdr
tdr_r2 = tdStats(m = y_pred,o = y_true,"r2")

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd", "tdr"),
  R_squared = c(r_squared_base, r_squared_metrics, r_squared_yardstick, 
                r_squared_mlmetrics, r_squared_modelmetrics, 
                r_squared_caret, r_squared_forecast, r_squared_e1071, 
                r_squared_hydroGOF, r_squared_simstudy, r_squared_rminer, 
                r_squared_fnn, r_squared_simEd, tdr_r2)
)

print(results)
# Out:
#          Method           R_squared
# 1        Base-R 0.86244135611224215
# 2       Metrics                  NA
# 3     yardstick 0.92445002422664324
# 4     MLmetrics 0.86244135611224215
# 5  ModelMetrics                  NA
# 6         caret 0.92445002422664380
# 7      forecast                  NA
# 8         e1071                  NA
# 9      hydroGOF                  NA
# 10     simstudy                  NA
# 11       rminer 0.92445002422664380
# 12          FNN                  NA
# 13        simEd                  NA
# 14          tdr 0.92445002422664380

# %% [markdown]
# # MAPE

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
mape_safe <- function(y_true, y_pred) {
  
  non_zero_indices <- y_true != 0
  y_true_non_zero <- y_true[non_zero_indices]
  y_pred_non_zero <- y_pred[non_zero_indices]
  
  mape_value <- mean(abs((y_true_non_zero - y_pred_non_zero) / y_true_non_zero)) * 100
  return(mape_value)
}

# 1. Base-R
mape_base <- mape(y_true, y_pred)

# 2. Metrics
mape_metrics <- Metrics::mape(y_true, y_pred)

# 3. yardstick
mape_yardstick <- yardstick::mape_vec(y_true, y_pred)

# 4. MLmetrics
mape_mlmetrics <- MLmetrics::MAPE(y_pred, y_true)

# 5. ModelMetrics
mape_modelmetrics <- NA

# 6. caret
mape_caret <- NA

# 7. forecast
mape_forecast <- NA

# 8. e1071
mape_e1071 <- NA

# 9. hydroGOF
mape_hydroGOF <- NA

# 10. simstudy
mape_simstudy <- NA

# 11. rminer
mape_rminer <- NA

# 12. FNN
mape_fnn <- NA

# 13. simEd
mape_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  MAPE = c(mape_base, mape_metrics, mape_yardstick, mape_mlmetrics, 
           mape_modelmetrics, mape_caret, mape_forecast, mape_e1071, 
           mape_hydroGOF, mape_simstudy, mape_rminer, mape_fnn, 
           mape_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
#          Method                 MAPE
# 1        Base-R 65.10358201950525370
# 2       Metrics  0.65103582019505257
# 3     yardstick 65.10358201950525370
# 4     MLmetrics  0.65103582019505257
# 5  ModelMetrics                   NA
# 6         caret                   NA
# 7      forecast                   NA
# 8         e1071                   NA
# 9      hydroGOF                   NA
# 10     simstudy                   NA
# 11       rminer                   NA
# 12          FNN                   NA
# 13        simEd                   NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
mape_safe <- function(y_true, y_pred) {
  
  non_zero_indices <- y_true != 0
  y_true_non_zero <- y_true[non_zero_indices]
  y_pred_non_zero <- y_pred[non_zero_indices]
  
  
  mape_value <- mean(abs((y_true_non_zero - y_pred_non_zero) / y_true_non_zero)) * 100
  return(mape_value)
}

# 1. Base-R
mape_base <- mape(y_true, y_pred)

# 2. Metrics
mape_metrics <- Metrics::mape(y_true, y_pred)

# 3. yardstick
mape_yardstick <- yardstick::mape_vec(y_true, y_pred)

# 4. MLmetrics
mape_mlmetrics <- MLmetrics::MAPE(y_pred, y_true)

# 5. ModelMetrics
mape_modelmetrics <- NA

# 6. caret
mape_caret <- NA

# 7. forecast
mape_forecast <- NA

# 8. e1071
mape_e1071 <- NA

# 9. hydroGOF
mape_hydroGOF <- NA

# 10. simstudy
mape_simstudy <- NA

# 11. rminer
mape_rminer <- NA

# 12. FNN
mape_fnn <- NA

# 13. simEd
mape_simEd <- NA

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  MAPE = c(mape_base, mape_metrics, mape_yardstick, mape_mlmetrics, 
           mape_modelmetrics, mape_caret, mape_forecast, mape_e1071, 
           mape_hydroGOF, mape_simstudy, mape_rminer, mape_fnn, 
           mape_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   2176.4299999999998
# 2 1521   1543.0300000000000
# 3 2799   1988.4900000000000
# 4 1452   1713.4500000000000
# 5 1269   1582.0300000000000
# 6 2413   1798.1500000000001
#          Method                 MAPE
# 1        Base-R 72.99188134467912903
# 2       Metrics  0.72991881344679133
# 3     yardstick 72.99188134467912903
# 4     MLmetrics  0.72991881344679133
# 5  ModelMetrics                   NA
# 6         caret                   NA
# 7      forecast                   NA
# 8         e1071                   NA
# 9      hydroGOF                   NA
# 10     simstudy                   NA
# 11       rminer                   NA
# 12          FNN                   NA
# 13        simEd                   NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)

data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

mape_safe <- function(y_true, y_pred) {
  
  non_zero_indices <- y_true != 0
  y_true_non_zero <- y_true[non_zero_indices]
  y_pred_non_zero <- y_pred[non_zero_indices]
  
  
  mape_value <- mean(abs((y_true_non_zero - y_pred_non_zero) / y_true_non_zero)) * 100
  return(mape_value)
}

# 1. Base-R
mape_base <- mape(y_true, y_pred)

# 2. Metrics
mape_metrics <- Metrics::mape(y_true, y_pred)

# 3. yardstick
mape_yardstick <- yardstick::mape_vec(y_true, y_pred)

# 4. MLmetrics
mape_mlmetrics <- MLmetrics::MAPE(y_pred, y_true)

# 5. ModelMetrics
mape_modelmetrics <- NA

# 6. caret
mape_caret <- NA

# 7. forecast
mape_forecast <- NA

# 8. e1071
mape_e1071 <- NA

# 9. hydroGOF
mape_hydroGOF <- NA

# 10. simstudy
mape_simstudy <- NA

# 11. rminer
mape_rminer <- NA

# 12. FNN
mape_fnn <- NA

# 13. simEd
mape_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  MAPE = c(mape_base, mape_metrics, mape_yardstick, mape_mlmetrics, 
           mape_modelmetrics, mape_caret, mape_forecast, mape_e1071, 
           mape_hydroGOF, mape_simstudy, mape_rminer, mape_fnn, 
           mape_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
#          Method                 MAPE
# 1        Base-R 65.13636119469182972
# 2       Metrics  0.65136361194691828
# 3     yardstick 65.13636119469182972
# 4     MLmetrics  0.65136361194691828
# 5  ModelMetrics                   NA
# 6         caret                   NA
# 7      forecast                   NA
# 8         e1071                   NA
# 9      hydroGOF                   NA
# 10     simstudy                   NA
# 11       rminer                   NA
# 12          FNN                   NA
# 13        simEd                   NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
y_true = c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred = c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)

mape_safe <- function(y_true, y_pred) {
  
  non_zero_indices <- y_true != 0
  y_true_non_zero <- y_true[non_zero_indices]
  y_pred_non_zero <- y_pred[non_zero_indices]
  
  
  mape_value <- mean(abs((y_true_non_zero - y_pred_non_zero) / y_true_non_zero)) * 100
  return(mape_value)
}

# 1. Base-R
mape_base <- mape(y_true, y_pred)

# 2. Metrics
mape_metrics <- Metrics::mape(y_true, y_pred)

# 3. yardstick
mape_yardstick <- yardstick::mape_vec(y_true, y_pred)

# 4. MLmetrics
mape_mlmetrics <- MLmetrics::MAPE(y_pred, y_true)

# 5. ModelMetrics
mape_modelmetrics <- NA

# 6. caret
mape_caret <- NA

# 7. forecast
mape_forecast <- NA

# 8. e1071
mape_e1071 <- NA

# 9. hydroGOF
mape_hydroGOF <- NA

# 10. simstudy
mape_simstudy <- NA

# 11. rminer
mape_rminer <- NA

# 12. FNN
mape_fnn <- NA

# 13. simEd
mape_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  MAPE = c(mape_base, mape_metrics, mape_yardstick, mape_mlmetrics, 
           mape_modelmetrics, mape_caret, mape_forecast, mape_e1071, 
           mape_hydroGOF, mape_simstudy, mape_rminer, mape_fnn, 
           mape_simEd)
)

print(results)
# Out:
#          Method                 MAPE
# 1        Base-R 26.32725714522949900
# 2       Metrics  0.26327257145229499
# 3     yardstick 26.32725714522949900
# 4     MLmetrics  0.26327257145229499
# 5  ModelMetrics                   NA
# 6         caret                   NA
# 7      forecast                   NA
# 8         e1071                   NA
# 9      hydroGOF                   NA
# 10     simstudy                   NA
# 11       rminer                   NA
# 12          FNN                   NA
# 13        simEd                   NA

# %% [markdown]
# # MSLE

# %%
library(Metrics)       # For rmse function
library(yardstick)     # For various metrics
library(ModelMetrics)  # For rmse function
library(caret)         # For rmse function
library(forecast)      # For accuracy function
library(e1071)         # For various metrics
library(hydroGOF)      # For various metrics
library(simstudy)      # For various metrics
library(rminer)        # For mmetric function
library(FNN)           # For various metrics
library(simEd)         # For various metrics
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
msle <- function(y_true, y_pred) {
  mean((log(y_true + 1) - log(y_pred + 1))^2)
}


# 1. Base-R
msle_base <- msle(y_true, y_pred)

# 2. Metrics
msle_metrics <- Metrics::msle(y_true, y_pred)

# 3. yardstick
msle_yardstick <- NA

# 4. MLmetrics
msle_mlmetrics <- NA

# 5. ModelMetrics
msle_modelmetrics <- ModelMetrics::msle(y_true, y_pred)

# 6. caret
msle_caret <- NA

# 7. forecast
msle_forecast <- NA

# 8. e1071
msle_e1071 <- NA

# 9. hydroGOF
msle_hydroGOF <- NA

# 10. simstudy
msle_simstudy <- NA
# 11. rminer
msle_rminer <- NA
# 12. FNN
msle_fnn <- NA
# 13. simEd
msle_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  MSLE = c(msle_base, msle_metrics, msle_yardstick, msle_mlmetrics, 
           msle_modelmetrics, msle_caret, msle_forecast, msle_e1071, 
           msle_hydroGOF, msle_simstudy, msle_rminer, msle_fnn, 
           msle_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
#          Method                MSLE
# 1        Base-R 0.36766624906538237
# 2       Metrics 0.36766624906538237
# 3     yardstick                  NA
# 4     MLmetrics                  NA
# 5  ModelMetrics 0.36766624906538237
# 6         caret                  NA
# 7      forecast                  NA
# 8         e1071                  NA
# 9      hydroGOF                  NA
# 10     simstudy                  NA
# 11       rminer                  NA
# 12          FNN                  NA
# 13        simEd                  NA

# %%
library(Metrics)       # For rmse function
library(yardstick)     # For various metrics
library(ModelMetrics)  # For rmse function
library(caret)         # For rmse function
library(forecast)      # For accuracy function
library(e1071)         # For various metrics
library(hydroGOF)      # For various metrics
library(simstudy)      # For various metrics
library(rminer)        # For mmetric function
library(FNN)           # For various metrics
library(simEd)         # For various metrics
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
msle <- function(y_true, y_pred) {
  mean((log(y_true + 1) - log(y_pred + 1))^2)
}


# 1. Base-R
msle_base <- msle(y_true, y_pred)

# 2. Metrics
msle_metrics <- Metrics::msle(y_true, y_pred)

# 3. yardstick
msle_yardstick <- NA

# 4. MLmetrics
msle_mlmetrics <- NA

# 5. ModelMetrics
msle_modelmetrics <- ModelMetrics::msle(y_true, y_pred)

# 6. caret
msle_caret <- NA

# 7. forecast
msle_forecast <- NA

# 8. e1071
msle_e1071 <- NA

# 9. hydroGOF
msle_hydroGOF <- NA

# 10. simstudy
msle_simstudy <- NA
# 11. rminer
msle_rminer <- NA
# 12. FNN
msle_fnn <- NA
# 13. simEd
msle_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  MSLE = c(msle_base, msle_metrics, msle_yardstick, msle_mlmetrics, 
           msle_modelmetrics, msle_caret, msle_forecast, msle_e1071, 
           msle_hydroGOF, msle_simstudy, msle_rminer, msle_fnn, 
           msle_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   2176.4299999999998
# 2 1521   1543.0300000000000
# 3 2799   1988.4900000000000
# 4 1452   1713.4500000000000
# 5 1269   1582.0300000000000
# 6 2413   1798.1500000000001
#          Method                MSLE
# 1        Base-R 0.40743171638840153
# 2       Metrics 0.40743171638840153
# 3     yardstick                  NA
# 4     MLmetrics                  NA
# 5  ModelMetrics 0.40743171638840153
# 6         caret                  NA
# 7      forecast                  NA
# 8         e1071                  NA
# 9      hydroGOF                  NA
# 10     simstudy                  NA
# 11       rminer                  NA
# 12          FNN                  NA
# 13        simEd                  NA

# %%
library(Metrics)       # For rmse function
library(yardstick)     # For various metrics
library(ModelMetrics)  # For rmse function
library(caret)         # For rmse function
library(forecast)      # For accuracy function
library(e1071)         # For various metrics
library(hydroGOF)      # For various metrics
library(simstudy)      # For various metrics
library(rminer)        # For mmetric function
library(FNN)           # For various metrics
library(simEd)         # For various metrics
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
msle <- function(y_true, y_pred) {
  mean((log(y_true + 1) - log(y_pred + 1))^2)
}


# 1. Base-R
msle_base <- msle(y_true, y_pred)

# 2. Metrics
msle_metrics <- Metrics::msle(y_true, y_pred)

# 3. yardstick
msle_yardstick <- NA

# 4. MLmetrics
msle_mlmetrics <- NA

# 5. ModelMetrics
msle_modelmetrics <- ModelMetrics::msle(y_true, y_pred)

# 6. caret
msle_caret <- NA

# 7. forecast
msle_forecast <- NA

# 8. e1071
msle_e1071 <- NA

# 9. hydroGOF
msle_hydroGOF <- NA

# 10. simstudy
msle_simstudy <- NA
# 11. rminer
msle_rminer <- NA
# 12. FNN
msle_fnn <- NA
# 13. simEd
msle_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  MSLE = c(msle_base, msle_metrics, msle_yardstick, msle_mlmetrics, 
           msle_modelmetrics, msle_caret, msle_forecast, msle_e1071, 
           msle_hydroGOF, msle_simstudy, msle_rminer, msle_fnn, 
           msle_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
#          Method                MSLE
# 1        Base-R 0.38165387269100309
# 2       Metrics 0.38165387269100309
# 3     yardstick                  NA
# 4     MLmetrics                  NA
# 5  ModelMetrics 0.38165387269100309
# 6         caret                  NA
# 7      forecast                  NA
# 8         e1071                  NA
# 9      hydroGOF                  NA
# 10     simstudy                  NA
# 11       rminer                  NA
# 12          FNN                  NA
# 13        simEd                  NA

# %%
library(Metrics)       # For rmse function
library(yardstick)     # For various metrics
library(ModelMetrics)  # For rmse function
library(caret)         # For rmse function
library(forecast)      # For accuracy function
library(e1071)         # For various metrics
library(hydroGOF)      # For various metrics
library(simstudy)      # For various metrics
library(rminer)        # For mmetric function
library(FNN)           # For various metrics
library(simEd)         # For various metrics
y_true = c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred = c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)
msle <- function(y_true, y_pred) {
  mean((log(y_true + 1) - log(y_pred + 1))^2)
}


# 1. Base-R
msle_base <- msle(y_true, y_pred)

# 2. Metrics
msle_metrics <- Metrics::msle(y_true, y_pred)

# 3. yardstick
msle_yardstick <- NA

# 4. MLmetrics
msle_mlmetrics <- NA

# 5. ModelMetrics
msle_modelmetrics <- ModelMetrics::msle(y_true, y_pred)

# 6. caret
msle_caret <- NA

# 7. forecast
msle_forecast <- NA

# 8. e1071
msle_e1071 <- NA

# 9. hydroGOF
msle_hydroGOF <- NA

# 10. simstudy
msle_simstudy <- NA
# 11. rminer
msle_rminer <- NA
# 12. FNN
msle_fnn <- NA
# 13. simEd
msle_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  MSLE = c(msle_base, msle_metrics, msle_yardstick, msle_mlmetrics, 
           msle_modelmetrics, msle_caret, msle_forecast, msle_e1071, 
           msle_hydroGOF, msle_simstudy, msle_rminer, msle_fnn, 
           msle_simEd)
)

print(results)
# Out:
#          Method                 MSLE
# 1        Base-R 0.057042229411707772
# 2       Metrics 0.057042229411707772
# 3     yardstick                   NA
# 4     MLmetrics                   NA
# 5  ModelMetrics 0.057042229411707772
# 6         caret                   NA
# 7      forecast                   NA
# 8         e1071                   NA
# 9      hydroGOF                   NA
# 10     simstudy                   NA
# 11       rminer                   NA
# 12          FNN                   NA
# 13        simEd                   NA

# %% [markdown]
# # Explained Variance

# %%
y_true <- c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred <- c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)

explained_var <- function (actual, predict){
  return(1 - (var(actual - predict) / var(actual)))
}
exp_var = explained_var(y_true, y_pred)
cat("Explained Variance (base r): ", sprintf("%.15f", exp_var))
# Out:
# Explained Variance (base r):  0.876781446401700

# %%
library(readxl)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
explained_var <- function (actual, predict){
  return(1 - (var(actual - predict) / var(actual)))
}
exp_var = explained_var(y_true, y_pred)
cat("Explained Variance (base r): ", sprintf("%.15f", exp_var))
# Out:
# Warning message:
# "package 'readxl' was built under R version 4.3.3"
#   y_true y_pred
# 1  668   1294.89
# 2 1521   1462.99
# 3 2799   1454.69
# 4 1452   1463.34
# 5 1269   1325.45
# 6 2413   1778.14
# Explained Variance (base r):  0.002157772754937

# %%
library(readxl)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
explained_var <- function (actual, predict){
  return(1 - (var(actual - predict) / var(actual)))
}
exp_var = explained_var(y_true, y_pred)
cat("Explained Variance (base r): ", sprintf("%.15f", exp_var))
# Out:
#   y_true y_pred
# 1  668   2176.43
# 2 1521   1543.03
# 3 2799   1988.49
# 4 1452   1713.45
# 5 1269   1582.03
# 6 2413   1798.15
# Explained Variance (base r):  0.001649640087135

# %%
library(readxl)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
explained_var <- function (actual, predict){
  return(1 - (var(actual - predict) / var(actual)))
}
exp_var = explained_var(y_true, y_pred)
cat("Explained Variance (base r): ", sprintf("%.15f", exp_var))
# Out:
#   y_true y_pred
# 1  668   1589.26
# 2 1521   1253.49
# 3 2799   1712.96
# 4 1452   1839.24
# 5 1269   1441.64
# 6 2413   2151.62
# Explained Variance (base r):  0.065059012083353

# %% [markdown]
# # Median AE

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
median_ae <- function(y_true, y_pred) {
  median(abs(y_true - y_pred))
}


# 1. Base-R
median_ae_base <- median_ae(y_true, y_pred)

# 2. Metrics
median_ae_metrics <- Metrics::mdae(y_true, y_pred)
# 3. yardstick
median_ae_yardstick <- NA
# 4. MLmetrics
median_ae_mlmetrics <- MedianAE(y_pred, y_true)

# 5. ModelMetrics
median_ae_modelmetrics <- NA
# 6. caret
median_ae_caret <- NA

# 7. forecast
median_ae_forecast <- NA
# 8. e1071
median_ae_e1071 <- NA
# 9. hydroGOF
median_ae_hydroGOF <- NA
# 10. simstudy
median_ae_simstudy <- NA

# 11. rminer
median_ae_rminer <- NA
# 12. FNN
median_ae_fnn <- NA

# 13. simEd
median_ae_simEd <- NA

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  Median_AE = c(median_ae_base, median_ae_metrics, median_ae_yardstick, median_ae_mlmetrics, 
                median_ae_modelmetrics, median_ae_caret, median_ae_forecast, median_ae_e1071, 
                median_ae_hydroGOF, median_ae_simstudy, median_ae_rminer, median_ae_fnn, 
                median_ae_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
#          Method          Median_AE
# 1        Base-R 506.08500000000004
# 2       Metrics 506.08500000000004
# 3     yardstick                 NA
# 4     MLmetrics 506.08500000000004
# 5  ModelMetrics                 NA
# 6         caret                 NA
# 7      forecast                 NA
# 8         e1071                 NA
# 9      hydroGOF                 NA
# 10     simstudy                 NA
# 11       rminer                 NA
# 12          FNN                 NA
# 13        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
median_ae <- function(y_true, y_pred) {
  median(abs(y_true - y_pred))
}


# 1. Base-R
median_ae_base <- median_ae(y_true, y_pred)

# 2. Metrics
median_ae_metrics <- Metrics::mdae(y_true, y_pred)
# 3. yardstick
median_ae_yardstick <- NA
# 4. MLmetrics
median_ae_mlmetrics <- MedianAE(y_pred, y_true)

# 5. ModelMetrics
median_ae_modelmetrics <- NA
# 6. caret
median_ae_caret <- NA

# 7. forecast
median_ae_forecast <- NA
# 8. e1071
median_ae_e1071 <- NA
# 9. hydroGOF
median_ae_hydroGOF <- NA
# 10. simstudy
median_ae_simstudy <- NA

# 11. rminer
median_ae_rminer <- NA
# 12. FNN
median_ae_fnn <- NA

# 13. simEd
median_ae_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  Median_AE = c(median_ae_base, median_ae_metrics, median_ae_yardstick, median_ae_mlmetrics, 
                median_ae_modelmetrics, median_ae_caret, median_ae_forecast, median_ae_e1071, 
                median_ae_hydroGOF, median_ae_simstudy, median_ae_rminer, median_ae_fnn, 
                median_ae_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   2176.4299999999998
# 2 1521   1543.0300000000000
# 3 2799   1988.4900000000000
# 4 1452   1713.4500000000000
# 5 1269   1582.0300000000000
# 6 2413   1798.1500000000001
#          Method          Median_AE
# 1        Base-R 599.17500000000007
# 2       Metrics 599.17500000000007
# 3     yardstick                 NA
# 4     MLmetrics 599.17500000000007
# 5  ModelMetrics                 NA
# 6         caret                 NA
# 7      forecast                 NA
# 8         e1071                 NA
# 9      hydroGOF                 NA
# 10     simstudy                 NA
# 11       rminer                 NA
# 12          FNN                 NA
# 13        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
median_ae <- function(y_true, y_pred) {
  median(abs(y_true - y_pred))
}


# 1. Base-R
median_ae_base <- median_ae(y_true, y_pred)

# 2. Metrics
median_ae_metrics <- Metrics::mdae(y_true, y_pred)
# 3. yardstick
median_ae_yardstick <- NA
# 4. MLmetrics
median_ae_mlmetrics <- MedianAE(y_pred, y_true)

# 5. ModelMetrics
median_ae_modelmetrics <- NA
# 6. caret
median_ae_caret <- NA

# 7. forecast
median_ae_forecast <- NA
# 8. e1071
median_ae_e1071 <- NA
# 9. hydroGOF
median_ae_hydroGOF <- NA
# 10. simstudy
median_ae_simstudy <- NA

# 11. rminer
median_ae_rminer <- NA
# 12. FNN
median_ae_fnn <- NA

# 13. simEd
median_ae_simEd <- NA

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  Median_AE = c(median_ae_base, median_ae_metrics, median_ae_yardstick, median_ae_mlmetrics, 
                median_ae_modelmetrics, median_ae_caret, median_ae_forecast, median_ae_e1071, 
                median_ae_hydroGOF, median_ae_simstudy, median_ae_rminer, median_ae_fnn, 
                median_ae_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
#          Method          Median_AE
# 1        Base-R 625.80500000000006
# 2       Metrics 625.80500000000006
# 3     yardstick                 NA
# 4     MLmetrics 625.80500000000006
# 5  ModelMetrics                 NA
# 6         caret                 NA
# 7      forecast                 NA
# 8         e1071                 NA
# 9      hydroGOF                 NA
# 10     simstudy                 NA
# 11       rminer                 NA
# 12          FNN                 NA
# 13        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)

y_true = c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred = c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)
median_ae <- function(y_true, y_pred) {
  median(abs(y_true - y_pred))
}


# 1. Base-R
median_ae_base <- median_ae(y_true, y_pred)

# 2. Metrics
median_ae_metrics <- Metrics::mdae(y_true, y_pred)
# 3. yardstick
median_ae_yardstick <- NA
# 4. MLmetrics
median_ae_mlmetrics <- MedianAE(y_pred, y_true)

# 5. ModelMetrics
median_ae_modelmetrics <- NA
# 6. caret
median_ae_caret <- NA

# 7. forecast
median_ae_forecast <- NA
# 8. e1071
median_ae_e1071 <- NA
# 9. hydroGOF
median_ae_hydroGOF <- NA
# 10. simstudy
median_ae_simstudy <- NA

# 11. rminer
median_ae_rminer <- NA
# 12. FNN
median_ae_fnn <- NA

# 13. simEd
median_ae_simEd <- NA

results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  Median_AE = c(median_ae_base, median_ae_metrics, median_ae_yardstick, median_ae_mlmetrics, 
                median_ae_modelmetrics, median_ae_caret, median_ae_forecast, median_ae_e1071, 
                median_ae_hydroGOF, median_ae_simstudy, median_ae_rminer, median_ae_fnn, 
                median_ae_simEd)
)

print(results)
# Out:
#          Method Median_AE
# 1        Base-R       0.5
# 2       Metrics       0.5
# 3     yardstick        NA
# 4     MLmetrics       0.5
# 5  ModelMetrics        NA
# 6         caret        NA
# 7      forecast        NA
# 8         e1071        NA
# 9      hydroGOF        NA
# 10     simstudy        NA
# 11       rminer        NA
# 12          FNN        NA
# 13        simEd        NA

# %% [markdown]
# # Tweedie Deviance

# %%
library(tweedie)

data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
p <- 1.5  
deviance <- tweedie::tweedie.dev(y_true , y_pred, p)
total_deviance <- sum(deviance)

print(total_deviance)
# Out:
# Warning message:
# "package 'tweedie' is in use and will not be installed"
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
# [1] 1973.7757683114828

# %%
library(tweedie)

data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
p <- 1.5 
deviance <- tweedie::tweedie.dev(y_true , y_pred, p)
total_deviance <- sum(deviance)
print(total_deviance)
# Out:
# Warning message:
# "package 'tweedie' is in use and will not be installed"
#   y_true y_pred
# 1  668   2176.4299999999998
# 2 1521   1543.0300000000000
# 3 2799   1988.4900000000000
# 4 1452   1713.4500000000000
# 5 1269   1582.0300000000000
# 6 2413   1798.1500000000001
# [1] 2124.2068863324971

# %%
library(tweedie)

data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

p <- 1.5 
deviance <- tweedie::tweedie.dev(y_true , y_pred, p)
total_deviance <- sum(deviance)
print(total_deviance)
# Out:
# Warning message:
# "package 'tweedie' is in use and will not be installed"
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
# [1] 2163.7802639780298

# %%
library(tweedie)

y_true = c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred = c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)

p <- 1.5 
deviance <- tweedie::tweedie.dev(y_true , y_pred, p)
total_deviance <- sum(deviance)

print(total_deviance)
# Out:
# Warning message:
# "package 'tweedie' is in use and will not be installed"
# [1] Inf

# %% [markdown]
# # Huber

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_PT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred

delta <- 1
huber_loss <- function(y_true, y_pred, delta) {
  residuals <- abs(y_true - y_pred)
  loss <- ifelse(residuals <= delta, 
                 0.5 * residuals^2, 
                 delta * (residuals - 0.5 * delta))
  return(mean(loss))
}

# 1. Base-R
huber_base <- huber_loss(y_true, y_pred, delta)

# 2. Metrics Package
huber_metrics <- NA
# 3. yardstick Package
huber_yardstick <- huber_loss_vec(y_true, y_pred, delta = 1,na_rm = TRUE,case_weights = NULL)

# 4. MLmetrics Package
huber_mlmetrics <- NA

# 5. ModelMetrics Package
huber_modelmetrics <- NA
# 6. caret Package
huber_caret <- NA

# 7. forecast Package
huber_forecast <- NA

# 8. e1071 Package
huber_e1071 <- NA
# 9. hydroGOF Package
huber_hydroGOF <- NA

# 10. simstudy Package
huber_simstudy <- NA

# 11. rminer Package
huber_rminer <- NA
# 12. FNN Package
huber_fnn <- NA

# 13. simEd Package
huber_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  Huber_Loss = c(huber_base, huber_metrics, huber_yardstick, huber_mlmetrics, 
                 huber_modelmetrics, huber_caret, huber_forecast, huber_e1071, 
                 huber_hydroGOF, huber_simstudy, huber_rminer, huber_fnn, 
                 huber_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1589.2600000000000
# 2 1521   1253.4900000000000
# 3 2799   1712.9600000000000
# 4 1452   1839.2400000000000
# 5 1269   1441.6400000000001
# 6 2413   2151.6199999999999
#          Method         Huber_Loss
# 1        Base-R 657.37516853932584
# 2       Metrics                 NA
# 3     yardstick 657.37516853932584
# 4     MLmetrics                 NA
# 5  ModelMetrics                 NA
# 6         caret                 NA
# 7      forecast                 NA
# 8         e1071                 NA
# 9      hydroGOF                 NA
# 10     simstudy                 NA
# 11       rminer                 NA
# 12          FNN                 NA
# 13        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
library(readxl)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_RF_CT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
delta <- 1

huber_loss <- function(y_true, y_pred, delta) {
  residuals <- abs(y_true - y_pred)
  loss <- ifelse(residuals <= delta, 
                 0.5 * residuals^2, 
                 delta * (residuals - 0.5 * delta))
  return(mean(loss))
}

# 1. Base-R
huber_base <- huber_loss(y_true, y_pred, delta)

# 2. Metrics Package
huber_metrics <- NA
# 3. yardstick Package
huber_yardstick <- huber_loss_vec(y_true, y_pred, delta = 1,na_rm = TRUE,case_weights = NULL)

# 4. MLmetrics Package
huber_mlmetrics <- NA

# 5. ModelMetrics Package
huber_modelmetrics <- NA
# 6. caret Package
huber_caret <- NA

# 7. forecast Package
huber_forecast <- NA

# 8. e1071 Package
huber_e1071 <- NA
# 9. hydroGOF Package
huber_hydroGOF <- NA

# 10. simstudy Package
huber_simstudy <- NA

# 11. rminer Package
huber_rminer <- NA
# 12. FNN Package
huber_fnn <- NA

# 13. simEd Package
huber_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  Huber_Loss = c(huber_base, huber_metrics, huber_yardstick, huber_mlmetrics, 
                 huber_modelmetrics, huber_caret, huber_forecast, huber_e1071, 
                 huber_hydroGOF, huber_simstudy, huber_rminer, huber_fnn, 
                 huber_simEd)
)

print(results)
# Out:
# Warning message:
# "package 'readxl' was built under R version 4.3.3"
#   y_true y_pred
# 1  668   2176.43
# 2 1521   1543.03
# 3 2799   1988.49
# 4 1452   1713.45
# 5 1269   1582.03
# 6 2413   1798.15
#          Method Huber_Loss
# 1        Base-R   699.5804
# 2       Metrics         NA
# 3     yardstick   699.5804
# 4     MLmetrics         NA
# 5  ModelMetrics         NA
# 6         caret         NA
# 7      forecast         NA
# 8         e1071         NA
# 9      hydroGOF         NA
# 10     simstudy         NA
# 11       rminer         NA
# 12          FNN         NA
# 13        simEd         NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
data <- read_excel("C:/Users/SADEGHI/Desktop/regression_data.xlsx", sheet="HC_DF_SPT_Head and Neck")
head(data)
y_true  <- data$y_true
y_pred <- data$y_pred
delta <- 1

huber_loss <- function(y_true, y_pred, delta) {
  residuals <- abs(y_true - y_pred)
  loss <- ifelse(residuals <= delta, 
                 0.5 * residuals^2, 
                 delta * (residuals - 0.5 * delta))
  return(mean(loss))
}

# 1. Base-R
huber_base <- huber_loss(y_true, y_pred, delta)

# 2. Metrics Package
huber_metrics <- NA
# 3. yardstick Package
huber_yardstick <- huber_loss_vec(y_true, y_pred, delta = 1,na_rm = TRUE,case_weights = NULL)

# 4. MLmetrics Package
huber_mlmetrics <- NA

# 5. ModelMetrics Package
huber_modelmetrics <- NA
# 6. caret Package
huber_caret <- NA

# 7. forecast Package
huber_forecast <- NA

# 8. e1071 Package
huber_e1071 <- NA
# 9. hydroGOF Package
huber_hydroGOF <- NA

# 10. simstudy Package
huber_simstudy <- NA

# 11. rminer Package
huber_rminer <- NA
# 12. FNN Package
huber_fnn <- NA

# 13. simEd Package
huber_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  Huber_Loss = c(huber_base, huber_metrics, huber_yardstick, huber_mlmetrics, 
                 huber_modelmetrics, huber_caret, huber_forecast, huber_e1071, 
                 huber_hydroGOF, huber_simstudy, huber_rminer, huber_fnn, 
                 huber_simEd)
)

print(results)
# Out:
#   y_true y_pred
# 1  668   1294.8900000000001
# 2 1521   1462.9900000000000
# 3 2799   1454.6900000000001
# 4 1452   1463.3399999999999
# 5 1269   1325.4500000000000
# 6 2413   1778.1400000000001
#          Method         Huber_Loss
# 1        Base-R 698.79056179775284
# 2       Metrics                 NA
# 3     yardstick 698.79056179775284
# 4     MLmetrics                 NA
# 5  ModelMetrics                 NA
# 6         caret                 NA
# 7      forecast                 NA
# 8         e1071                 NA
# 9      hydroGOF                 NA
# 10     simstudy                 NA
# 11       rminer                 NA
# 12          FNN                 NA
# 13        simEd                 NA

# %%
library(Metrics)
library(yardstick)
library(MLmetrics)
library(ModelMetrics)
library(caret)
library(forecast)
library(e1071)
library(hydroGOF)
library(simstudy)
library(rminer)
library(FNN)
library(simEd)
y_true = c(3.0, 0.5, 2.0, 7.0, 2.4, 3.7, 6.2)
y_pred = c(2.5, 0.0, 2.0, 8.0, 2.5, 2.0, 6.0)
delta <- 1
huber_loss <- function(y_true, y_pred, delta) {
  residuals <- abs(y_true - y_pred)
  loss <- ifelse(residuals <= delta, 
                 0.5 * residuals^2, 
                 delta * (residuals - 0.5 * delta))
  return(mean(loss))
}

# 1. Base-R
huber_base <- huber_loss(y_true, y_pred, delta)

# 2. Metrics Package
huber_metrics <- NA
# 3. yardstick Package
huber_yardstick <- huber_loss_vec(y_true, y_pred, delta = 1,na_rm = TRUE,case_weights = NULL)

# 4. MLmetrics Package
huber_mlmetrics <- NA

# 5. ModelMetrics Package
huber_modelmetrics <- NA
# 6. caret Package
huber_caret <- NA

# 7. forecast Package
huber_forecast <- NA

# 8. e1071 Package
huber_e1071 <- NA
# 9. hydroGOF Package
huber_hydroGOF <- NA

# 10. simstudy Package
huber_simstudy <- NA

# 11. rminer Package
huber_rminer <- NA
# 12. FNN Package
huber_fnn <- NA

# 13. simEd Package
huber_simEd <- NA
results <- data.frame(
  Method = c("Base-R", "Metrics", "yardstick", "MLmetrics", "ModelMetrics", 
             "caret", "forecast", "e1071", "hydroGOF", "simstudy", 
             "rminer", "FNN", "simEd"),
  Huber_Loss = c(huber_base, huber_metrics, huber_yardstick, huber_mlmetrics, 
                 huber_modelmetrics, huber_caret, huber_forecast, huber_e1071, 
                 huber_hydroGOF, huber_simstudy, huber_rminer, huber_fnn, 
                 huber_simEd)
)

print(results)
# Out:
#          Method         Huber_Loss
# 1        Base-R 0.2821428571428572
# 2       Metrics                 NA
# 3     yardstick 0.2821428571428572
# 4     MLmetrics                 NA
# 5  ModelMetrics                 NA
# 6         caret                 NA
# 7      forecast                 NA
# 8         e1071                 NA
# 9      hydroGOF                 NA
# 10     simstudy                 NA
# 11       rminer                 NA
# 12          FNN                 NA
# 13        simEd                 NA
